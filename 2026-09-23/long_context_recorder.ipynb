# %%
from langchain_core.prompts import PromptTemplate
from langchain_community.document_transformers import LongContextReorder
from langchain_community.vectorstores import Chroma
from langchain_openai import OpenAIEmbeddings
from dotenv import load_dotenv
from langchain_teddynote import logging

logging.langsmith("CH10-Retriever")
load_dotenv()

embeddings = OpenAIEmbeddings(model= "text-embedding-3-small")

texts = [
    "이건 그냥 내가 아무렇게나 적어본 글입니다.",
    "사용자와 대화하는 것처럼 설계된 AI인 ChatGPT는 다양한 질문에 답할 수 있습니다.",
    "아이폰, 아이패드, 맥북 등은 애플이 출시한 대표적인 제품들입니다.",
    "챗GPT는 OpenAI에 의해 개발되었으며, 지속적으로 개선되고 있습니다.",
    "챗지피티는 사용자의 질문을 이해하고 적절한 답변을 생성하기 위해 대량의 데이터를 학습했습니다.",
    "애플 워치와 에어팟 같은 웨어러블 기기도 애플의 인기 제품군에 속합니다.",
    "ChatGPT는 복잡한 문제를 해결하거나 창의적인 아이디어를 제안하는 데에도 사용될 수 잇습니다.",
    "비트코인은 디지털 금이라고도 불리며, 가치 저장 수단으로서 인기를 얻고 잇습니다.",
    "ChatGPT의 기능은 지속적인 학습과 업데이트를 통해 더욱 발전하고 있습니다.",
    "FIFA 월드컵은 네 번째 해마다 열리며, 국제 축구에서 가장 큰 행사 입니다.",
]
retriever = Chroma.from_texts(texts, embedding=embeddings).as_retriever(
    search_kwargs={"k":10}
)

query = "ChatGPT에 대해 무엇을 말해줄 수 있나요?"
docs = retriever.invoke(query)
docs
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11816\3522204885.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_transformers import LongContextReorder
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# CH10-Retriever
# [Document(metadata={}, page_content='ChatGPT는 복잡한 문제를 해결하거나 창의적인 아이디어를 제안하는 데에도 사용될 수 잇습니다.'),
#  Document(metadata={}, page_content='ChatGPT의 기능은 지속적인 학습과 업데이트를 통해 더욱 발전하고 있습니다.'),
#  Document(metadata={}, page_content='사용자와 대화하는 것처럼 설계된 AI인 ChatGPT는 다양한 질문에 답할 수 있습니다.'),
#  Document(metadata={}, page_content='챗GPT는 OpenAI에 의해 개발되었으며, 지속적으로 개선되고 있습니다.'),
#  Document(metadata={}, page_content='이건 그냥 내가 아무렇게나 적어본 글입니다.'),
#  Document(metadata={}, page_content='챗지피티는 사용자의 질문을 이해하고 적절한 답변을 생성하기 위해 대량의 데이터를 학습했습니다.'),
#  Document(metadata={}, page_content='비트코인은 디지털 금이라고도 불리며, 가치 저장 수단으로서 인기를 얻고 잇습니다.'),
#  Document(metadata={}, page_content='아이폰, 아이패드, 맥북 등은 애플이 출시한 대표적인 제품들입니다.'),
#  Document(metadata={}, page_content='애플 워치와 에어팟 같은 웨어러블 기기도 애플의 인기 제품군에 속합니다.'),
#  Document(metadata={}, page_content='FIFA 월드컵은 네 번째 해마다 열리며, 국제 축구에서 가장 큰 행사 입니다.')]

# %%
reordering = LongContextReorder()
reordered_docs = reordering.transform_documents(docs)

reordered_docs
# Out:
# [Document(metadata={}, page_content='ChatGPT의 기능은 지속적인 학습과 업데이트를 통해 더욱 발전하고 있습니다.'),
#  Document(metadata={}, page_content='챗GPT는 OpenAI에 의해 개발되었으며, 지속적으로 개선되고 있습니다.'),
#  Document(metadata={}, page_content='챗지피티는 사용자의 질문을 이해하고 적절한 답변을 생성하기 위해 대량의 데이터를 학습했습니다.'),
#  Document(metadata={}, page_content='아이폰, 아이패드, 맥북 등은 애플이 출시한 대표적인 제품들입니다.'),
#  Document(metadata={}, page_content='FIFA 월드컵은 네 번째 해마다 열리며, 국제 축구에서 가장 큰 행사 입니다.'),
#  Document(metadata={}, page_content='애플 워치와 에어팟 같은 웨어러블 기기도 애플의 인기 제품군에 속합니다.'),
#  Document(metadata={}, page_content='비트코인은 디지털 금이라고도 불리며, 가치 저장 수단으로서 인기를 얻고 잇습니다.'),
#  Document(metadata={}, page_content='이건 그냥 내가 아무렇게나 적어본 글입니다.'),
#  Document(metadata={}, page_content='사용자와 대화하는 것처럼 설계된 AI인 ChatGPT는 다양한 질문에 답할 수 있습니다.'),
#  Document(metadata={}, page_content='ChatGPT는 복잡한 문제를 해결하거나 창의적인 아이디어를 제안하는 데에도 사용될 수 잇습니다.')]

# %%
def format_docs(docs):
    return "\n".join(doc.page_content for i, doc in enumerate(docs))

print(format_docs(docs))
# Out:
# ChatGPT는 복잡한 문제를 해결하거나 창의적인 아이디어를 제안하는 데에도 사용될 수 잇습니다.
# ChatGPT의 기능은 지속적인 학습과 업데이트를 통해 더욱 발전하고 있습니다.
# 사용자와 대화하는 것처럼 설계된 AI인 ChatGPT는 다양한 질문에 답할 수 있습니다.
# 챗GPT는 OpenAI에 의해 개발되었으며, 지속적으로 개선되고 있습니다.
# 이건 그냥 내가 아무렇게나 적어본 글입니다.
# 챗지피티는 사용자의 질문을 이해하고 적절한 답변을 생성하기 위해 대량의 데이터를 학습했습니다.
# 비트코인은 디지털 금이라고도 불리며, 가치 저장 수단으로서 인기를 얻고 잇습니다.
# 아이폰, 아이패드, 맥북 등은 애플이 출시한 대표적인 제품들입니다.
# 애플 워치와 에어팟 같은 웨어러블 기기도 애플의 인기 제품군에 속합니다.
# FIFA 월드컵은 네 번째 해마다 열리며, 국제 축구에서 가장 큰 행사 입니다.

# %%
def format_docs(docs):
    return "\n".join(
        [
            f"[{i}] {doc.page_content} [source: this is metta data temporary]"
            for i, doc in enumerate(docs)
        ]
    )

def reorder_documents(docs):
    reordering = LongContextReorder()
    reordered_docs = reordering.transform_documents(docs)
    combined = format_docs(reordered_docs)
    print(combined)
    return combined

_ = reorder_documents(docs)
# Out:
# [0] ChatGPT의 기능은 지속적인 학습과 업데이트를 통해 더욱 발전하고 있습니다. [source: this is metta data temporary]
# [1] 챗GPT는 OpenAI에 의해 개발되었으며, 지속적으로 개선되고 있습니다. [source: this is metta data temporary]
# [2] 챗지피티는 사용자의 질문을 이해하고 적절한 답변을 생성하기 위해 대량의 데이터를 학습했습니다. [source: this is metta data temporary]
# [3] 아이폰, 아이패드, 맥북 등은 애플이 출시한 대표적인 제품들입니다. [source: this is metta data temporary]
# [4] FIFA 월드컵은 네 번째 해마다 열리며, 국제 축구에서 가장 큰 행사 입니다. [source: this is metta data temporary]
# [5] 애플 워치와 에어팟 같은 웨어러블 기기도 애플의 인기 제품군에 속합니다. [source: this is metta data temporary]
# [6] 비트코인은 디지털 금이라고도 불리며, 가치 저장 수단으로서 인기를 얻고 잇습니다. [source: this is metta data temporary]
# [7] 이건 그냥 내가 아무렇게나 적어본 글입니다. [source: this is metta data temporary]
# [8] 사용자와 대화하는 것처럼 설계된 AI인 ChatGPT는 다양한 질문에 답할 수 있습니다. [source: this is metta data temporary]
# [9] ChatGPT는 복잡한 문제를 해결하거나 창의적인 아이디어를 제안하는 데에도 사용될 수 잇습니다. [source: this is metta data temporary]

# %%
from langchain_core.prompts import ChatPromptTemplate
from operator import itemgetter
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnableLambda

template ="""Given this text extracts
{context}

-----
Please answer the following question:
{question}

Answer in the following languages: {language}"""

prompt = ChatPromptTemplate.from_template(template)

chain=(
    {
        "context": itemgetter("question")
        |retriever
        |RunnableLambda(reorder_documents),
        "question": itemgetter("question"),
        "language":itemgetter("language"),
    }
    |prompt
    |ChatOpenAI(model="gpt-4o-mini")
    |StrOutputParser()
)

# %%
answer = chain.invoke(
    {"question": "ChatGPT에 대해 무엇을 말해줄 수 있나요?", "language":"KOREAN"}
)
# Out:
# [0] ChatGPT의 기능은 지속적인 학습과 업데이트를 통해 더욱 발전하고 있습니다. [source: this is metta data temporary]
# [1] 챗GPT는 OpenAI에 의해 개발되었으며, 지속적으로 개선되고 있습니다. [source: this is metta data temporary]
# [2] 챗지피티는 사용자의 질문을 이해하고 적절한 답변을 생성하기 위해 대량의 데이터를 학습했습니다. [source: this is metta data temporary]
# [3] 아이폰, 아이패드, 맥북 등은 애플이 출시한 대표적인 제품들입니다. [source: this is metta data temporary]
# [4] FIFA 월드컵은 네 번째 해마다 열리며, 국제 축구에서 가장 큰 행사 입니다. [source: this is metta data temporary]
# [5] 애플 워치와 에어팟 같은 웨어러블 기기도 애플의 인기 제품군에 속합니다. [source: this is metta data temporary]
# [6] 비트코인은 디지털 금이라고도 불리며, 가치 저장 수단으로서 인기를 얻고 잇습니다. [source: this is metta data temporary]
# [7] 이건 그냥 내가 아무렇게나 적어본 글입니다. [source: this is metta data temporary]
# [8] 사용자와 대화하는 것처럼 설계된 AI인 ChatGPT는 다양한 질문에 답할 수 있습니다. [source: this is metta data temporary]
# [9] ChatGPT는 복잡한 문제를 해결하거나 창의적인 아이디어를 제안하는 데에도 사용될 수 잇습니다. [source: this is metta data temporary]

# %%
print(answer)
# Out:
# ChatGPT는 OpenAI에 의해 개발된 인공지능(AI) 모델로, 사용자의 질문을 이해하고 적절한 답변을 생성하는 능력을 가지고 있습니다. 이 모델은 대량의 데이터를 학습하여 다양한 주제에 대해 대화할 수 있도록 설계되었습니다. ChatGPT는 지속적인 학습과 업데이트를 통해 성능이 개선되고 있으며, 복잡한 문제를 해결하거나 창의적인 아이디어를 제안하는 데에도 유용하게 사용될 수 있습니다.
